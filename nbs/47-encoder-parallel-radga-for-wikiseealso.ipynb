# %% [markdown]
# # RADGA

# %%
#| default_exp 47-encoder-parallel-radga-for-wikiseealso

# %%
# %load_ext autoreload
# %autoreload 2

from nbdev.showdoc import *
import nbdev; nbdev.nbdev_export()

# %%
#| export
import os,sys,torch,pickle,torch.multiprocessing as mp, pickle
from xcai.basics import *
from xcai.models.PPP0XX import DBT020

# %%
os.environ['WANDB_MODE'] = 'disabled'

# %%
#| export
os.environ['CUDA_VISIBLE_DEVICES'] = '12,13,14,15'
os.environ['WANDB_PROJECT']='xc-nlg_38-radga-training-pipeline'

# %% [markdown]
# ## Data

# %%
#| export
data_dir = '/home/aiscuser/scratch/datasets'

# %%
block = XCBlock.from_cfg(data_dir, 'data_metas', valid_pct=0.001, tfm='rm', tokenizer='distilbert-base-uncased', 
                         smp_features=[('lbl2data|cat2lbl2data|hlk2lbl2data',1, 1), ('cat2data',1, 1), ('hlk2data',1,3)], 
                         n_data_meta_samples=50, n_lbl_meta_samples=50)
# Out:
# /home/aiscuser/.local/lib/python3.9/site-packages/xclib-0.97-py3.9-linux-x86_64.egg/xclib/data/data_utils.py:263: UserWarning: Header mis-match from inferred shape!
#   warnings.warn("Header mis-match from inferred shape!")
# /opt/conda/envs/ptca/lib/python3.9/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)

# %%
block.collator.tfms.tfms.append(RemoveColumnTfm(['phlk2data_idx', 'phlk2data_data2ptr', 'phlk2lbl_idx', 
                                                 'phlk2lbl_lbl2data2ptr', 'phlk2lbl_data2ptr', 'hlk2lbl_data2ptr']))

# %%
#| export
pkl_dir = f'{data_dir}/processed/'

# %%
with open(f'{pkl_dir}/wikiseealso_data-metas_distilbert-base-uncased_rm_radga-encoder-parallel.pkl', 'wb') as file: 
    pickle.dump(block, file)

# %%
#| export
with open(f'{pkl_dir}/wikiseealso_data-metas_distilbert-base-uncased_rm_radga-encoder-parallel.pkl', 'rb') as file: 
    block = pickle.load(file)

# %%
#| export
args = XCLearningArguments(
    output_dir='/home/aiscuser/outputs/47-encoder-parallel-radga-for-wikiseealso-1-0',
    logging_first_step=True,
    per_device_train_batch_size=600,
    per_device_eval_batch_size=100,
    representation_num_beams=200,
    representation_accumulation_steps=1,
    save_strategy="steps",
    evaluation_strategy='steps',
    eval_steps=1000,
    save_steps=1000,
    save_total_limit=5,
    num_train_epochs=300,
    predict_with_representation=True,
    adam_epsilon=1e-6,
    warmup_steps=100,
    weight_decay=0.01,
    learning_rate=2e-4,
    generation_num_beams=10,
    generation_length_penalty=1.5,
    predict_with_generation=True,
    representation_search_type='INDEX',
    group_by_cluster=True,
    num_clustering_warmup_epochs=10,
    num_cluster_update_epochs=5,
    num_cluster_size_update_epochs=10,
    clustering_type='EXPO',
    minimum_cluster_size=1,
    maximum_cluster_size=300,
    output_concatenation_weight=1.0,
    metric_for_best_model='P@1_REPR',
    target_indices_key='plbl2data_idx',
    target_pointer_key='plbl2data_data2ptr',
    fp16=True,
    label_names=['cat2data_idx', 'cat2data_input_ids', 'cat2data_attention_mask',
                 'cat2lbl2data_idx', 'cat2lbl2data_input_ids', 'cat2lbl2data_attention_mask',
                 'hlk2data_input_ids', 'hlk2data_attention_mask', 'hlk2data_idx',
                 'hlk2lbl2data_input_ids', 'hlk2lbl2data_attention_mask', 'hlk2lbl2data_idx'
                ],
)
# Out:
# /opt/conda/envs/ptca/lib/python3.9/site-packages/transformers/training_args.py:1474: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
#| export
test_dset = block.test.dset.sample(n=2000, seed=50)
metric = PrecRecl(block.n_lbl, test_dset.data.data_lbl_filterer, prop=block.train.dset.data.data_lbl,
                  pk=10, rk=200, rep_pk=[1, 3, 5, 10], rep_rk=[10, 100, 200])

# %%
#| export
bsz = max(args.per_device_train_batch_size, args.per_device_eval_batch_size)*torch.cuda.device_count()

model = DBT020.from_pretrained('distilbert-base-uncased', ig_tok=0, bsz=bsz, tn_targ=5000, tn_meta=5000, 
                               margin=0.3, tau=0.1, n_negatives=5, apply_softmax=True, lw=0.01, m_lw=0.3, 
                               pred_meta_prefix='cat', data_aug_meta_prefix='hlk2data', 
                               lbl2data_aug_meta_prefix='hlk2lbl', tie_word_embeddings=False)

model.init_dr_head()
# Out:
# Some weights of DBT020 were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['encoder.module.dr_layer_norm.bias', 'encoder.module.dr_layer_norm.weight', 'encoder.module.dr_projector.bias', 'encoder.module.dr_projector.weight', 'encoder.module.dr_transform.bias', 'encoder.module.dr_transform.weight', 'encoder.module.fuser.k.bias', 'encoder.module.fuser.k.weight', 'encoder.module.fuser.o.bias', 'encoder.module.fuser.o.weight', 'encoder.module.fuser.q.bias', 'encoder.module.fuser.q.weight', 'encoder.module.fuser.v.bias', 'encoder.module.fuser.v.weight', 'encoder.module.ln.bias', 'encoder.module.ln.weight', 'encoder.module.vocab_projector.weight', 'vocab_projector.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
#| export
trie = XCTrie.from_block(block)
# Out:
#   0%|          | 0/312330 [00:00<?, ?it/s]

# %%
#| export
learn = XCLearner(
    model=model, 
    args=args,
    trie=trie,
    train_dataset=block.train.dset,
    eval_dataset=test_dset,
    data_collator=block.collator,
    compute_metrics=metric,
)

# %%
learn.train()
# Out:
# [2024-06-01 16:26:53,231] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
#   0%|          | 0/1731 [00:00<?, ?it/s]
# node-0:4149074:4149074 [0] NCCL INFO Bootstrap : Using eth0:10.13.60.215<0>
# node-0:4149074:4149074 [0] NCCL INFO NET/Plugin : Plugin load (librccl-net.so) returned 2 : librccl-net.so: cannot open shared object file: No such file or directory
# node-0:4149074:4149074 [0] NCCL INFO NET/Plugin : No plugin found, using internal implementation
# node-0:4149074:4149074 [0] NCCL INFO Kernel version: 5.15.0-1042-azure
# RCCL version 2.17.1+hip5.7 HEAD:cbbb3d8+
#
# node-0:4149074:4151771 [3] /long_pathname_so_that_rpms_can_package_the_debug_info/src/extlibs/rccl/build/hipify/src/misc/ibvwrap.cc:222 NCCL WARN Call to ibv_open_device failed
#
# node-0:4149074:4151771 [3] /long_pathname_so_that_rpms_can_package_the_debug_info/src/extlibs/rccl/build/hipify/src/transport/net_ib.cc:199 NCCL WARN NET/IB : Unable to open device mlx5_0
#
# node-0:4149074:4151771 [3] /long_pathname_so_that_rpms_can_package_the_debug_info/src/extlibs/rccl/build/hipify/src/misc/ibvwrap.cc:222 NCCL WARN Call to ibv_open_device failed
#
# node-0:4149074:4151771 [3] /long_pathname_so_that_rpms_can_package_the_debug_info/src/extlibs/rccl/build/hipify/src/transport/net_ib.cc:199 NCCL WARN NET/IB : Unable to open device mlx5_1
#
# node-0:4149074:4151771 [3] /long_pathname_so_that_rpms_can_package_the_debug_info/src/extlibs/rccl/build/hipify/src/misc/ibvwrap.cc:222 NCCL WARN Call to ibv_open_device failed
#
# node-0:4149074:4151771 [3] /long_pathname_so_that_rpms_can_package_the_debug_info/src/extlibs/rccl/build/hipify/src/transport/net_ib.cc:199 NCCL WARN NET/IB : Unable to open device mlx5_2
#
# node-0:4149074:4151771 [3] /long_pathname_so_that_rpms_can_package_the_debug_info/src/extlibs/rccl/build/hipify/src/misc/ibvwrap.cc:222 NCCL WARN Call to ibv_open_device failed
#
# node-0:4149074:4151771 [3] /long_pathname_so_that_rpms_can_package_the_debug_info/src/extlibs/rccl/build/hipify/src/transport/net_ib.cc:199 NCCL WARN NET/IB : Unable to open device mlx5_3
#
# node-0:4149074:4151771 [3] /long_pathname_so_that_rpms_can_package_the_debug_info/src/extlibs/rccl/build/hipify/src/misc/ibvwrap.cc:222 NCCL WARN Call to ibv_open_device failed
#
# node-0:4149074:4151771 [3] /long_pathname_so_that_rpms_can_package_the_debug_info/src/extlibs/rccl/build/hipify/src/transport/net_ib.cc:199 NCCL WARN NET/IB : Unable to open device mlx5_4
#
# node-0:4149074:4151771 [3] /long_pathname_so_that_rpms_can_package_the_debug_info/src/extlibs/rccl/build/hipify/src/misc/ibvwrap.cc:222 NCCL WARN Call to ibv_open_device failed
#
# node-0:4149074:4151771 [3] /long_pathname_so_that_rpms_can_package_the_debug_info/src/extlibs/rccl/build/hipify/src/transport/net_ib.cc:199 NCCL WARN NET/IB : Unable to open device mlx5_5
#
# node-0:4149074:4151771 [3] /long_pathname_so_that_rpms_can_package_the_debug_info/src/extlibs/rccl/build/hipify/src/misc/ibvwrap.cc:222 NCCL WARN Call to ibv_open_device failed
#
# node-0:4149074:4151771 [3] /long_pathname_so_that_rpms_can_package_the_debug_info/src/extlibs/rccl/build/hipify/src/transport/net_ib.cc:199 NCCL WARN NET/IB : Unable to open device mlx5_6
#
# node-0:4149074:4151771 [3] /long_pathname_so_that_rpms_can_package_the_debug_info/src/extlibs/rccl/build/hipify/src/misc/ibvwrap.cc:222 NCCL WARN Call to ibv_open_device failed
#
# node-0:4149074:4151771 [3] /long_pathname_so_that_rpms_can_package_the_debug_info/src/extlibs/rccl/build/hipify/src/transport/net_ib.cc:199 NCCL WARN NET/IB : Unable to open device mlx5_7
#
# node-0:4149074:4151771 [3] /long_pathname_so_that_rpms_can_package_the_debug_info/src/extlibs/rccl/build/hipify/src/misc/ibvwrap.cc:222 NCCL WARN Call to ibv_open_device failed
#
# node-0:4149074:4151771 [3] /long_pathname_so_that_rpms_can_package_the_debug_info/src/extlibs/rccl/build/hipify/src/transport/net_ib.cc:199 NCCL WARN NET/IB : Unable to open device mlx5_8
# node-0:4149074:4151771 [3] NCCL INFO NET/IB : No device found.
# node-0:4149074:4151771 [3] NCCL INFO NET/Socket : Using [0]eth0:10.13.60.215<0>
# node-0:4149074:4151771 [3] NCCL INFO Using network Socket
# node-0:4149074:4151767 [0] NCCL INFO Using network Socket
# node-0:4149074:4151768 [1] NCCL INFO Using network Socket
# node-0:4149074:4151769 [2] NCCL INFO Using network Socket
# node-0:4149074:4151767 [0] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000d-0000-3130-303237343043/pci000d:00/000d:00:00.0/../max_link_speed, ignoring
# node-0:4149074:4151768 [1] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000d-0000-3130-303237343043/pci000d:00/000d:00:00.0/../max_link_speed, ignoring
# node-0:4149074:4151771 [3] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000d-0000-3130-303237343043/pci000d:00/000d:00:00.0/../max_link_speed, ignoring
# node-0:4149074:4151769 [2] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000d-0000-3130-303237343043/pci000d:00/000d:00:00.0/../max_link_speed, ignoring
# node-0:4149074:4151767 [0] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000d-0000-3130-303237343043/pci000d:00/000d:00:00.0/../max_link_width, ignoring
# node-0:4149074:4151768 [1] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000d-0000-3130-303237343043/pci000d:00/000d:00:00.0/../max_link_width, ignoring
# node-0:4149074:4151771 [3] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000d-0000-3130-303237343043/pci000d:00/000d:00:00.0/../max_link_width, ignoring
# node-0:4149074:4151769 [2] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000d-0000-3130-303237343043/pci000d:00/000d:00:00.0/../max_link_width, ignoring
# node-0:4149074:4151767 [0] NCCL INFO rocm_smi_lib: version 5.0.0.0
# node-0:4149074:4151771 [3] NCCL INFO rocm_smi_lib: version 5.0.0.0
# node-0:4149074:4151769 [2] NCCL INFO rocm_smi_lib: version 5.0.0.0
# node-0:4149074:4151768 [1] NCCL INFO rocm_smi_lib: version 5.0.0.0
# node-0:4149074:4151767 [0] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000e-0000-3130-303237343043/pci000e:00/000e:00:00.0/../max_link_speed, ignoring
# node-0:4149074:4151771 [3] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000e-0000-3130-303237343043/pci000e:00/000e:00:00.0/../max_link_speed, ignoring
# node-0:4149074:4151769 [2] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000e-0000-3130-303237343043/pci000e:00/000e:00:00.0/../max_link_speed, ignoring
# node-0:4149074:4151768 [1] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000e-0000-3130-303237343043/pci000e:00/000e:00:00.0/../max_link_speed, ignoring
# node-0:4149074:4151767 [0] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000e-0000-3130-303237343043/pci000e:00/000e:00:00.0/../max_link_width, ignoring
# node-0:4149074:4151771 [3] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000e-0000-3130-303237343043/pci000e:00/000e:00:00.0/../max_link_width, ignoring
# node-0:4149074:4151769 [2] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000e-0000-3130-303237343043/pci000e:00/000e:00:00.0/../max_link_width, ignoring
# node-0:4149074:4151768 [1] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000e-0000-3130-303237343043/pci000e:00/000e:00:00.0/../max_link_width, ignoring
# node-0:4149074:4151767 [0] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000f-0000-3130-303237343043/pci000f:00/000f:00:00.0/../max_link_speed, ignoring
# node-0:4149074:4151767 [0] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000f-0000-3130-303237343043/pci000f:00/000f:00:00.0/../max_link_width, ignoring
# node-0:4149074:4151771 [3] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000f-0000-3130-303237343043/pci000f:00/000f:00:00.0/../max_link_speed, ignoring
# node-0:4149074:4151771 [3] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000f-0000-3130-303237343043/pci000f:00/000f:00:00.0/../max_link_width, ignoring
# node-0:4149074:4151769 [2] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000f-0000-3130-303237343043/pci000f:00/000f:00:00.0/../max_link_speed, ignoring
# node-0:4149074:4151768 [1] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000f-0000-3130-303237343043/pci000f:00/000f:00:00.0/../max_link_speed, ignoring
# node-0:4149074:4151767 [0] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-0010-0000-3130-303237343043/pci0010:00/0010:00:00.0/../max_link_speed, ignoring
# node-0:4149074:4151769 [2] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000f-0000-3130-303237343043/pci000f:00/000f:00:00.0/../max_link_width, ignoring
# node-0:4149074:4151768 [1] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-000f-0000-3130-303237343043/pci000f:00/000f:00:00.0/../max_link_width, ignoring
# node-0:4149074:4151767 [0] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-0010-0000-3130-303237343043/pci0010:00/0010:00:00.0/../max_link_width, ignoring
# node-0:4149074:4151771 [3] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-0010-0000-3130-303237343043/pci0010:00/0010:00:00.0/../max_link_speed, ignoring
# node-0:4149074:4151771 [3] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-0010-0000-3130-303237343043/pci0010:00/0010:00:00.0/../max_link_width, ignoring
# node-0:4149074:4151769 [2] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-0010-0000-3130-303237343043/pci0010:00/0010:00:00.0/../max_link_speed, ignoring
# node-0:4149074:4151767 [0] NCCL INFO === System : maxBw 144.0 totalBw 216.0 ===
# node-0:4149074:4151767 [0] NCCL INFO CPU/2 (1/2/4)
# node-0:4149074:4151768 [1] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-0010-0000-3130-303237343043/pci0010:00/0010:00:00.0/../max_link_speed, ignoring
# node-0:4149074:4151767 [0] NCCL INFO + PCI[5000.0] - NIC/0
# node-0:4149074:4151767 [0] NCCL INFO + PCI[24.0] - GPU/D00000 (0)
# node-0:4149074:4151767 [0] NCCL INFO               + XGMI[144.0] - GPU/E00000
# node-0:4149074:4151767 [0] NCCL INFO               + XGMI[36.0] - GPU/F00000
# node-0:4149074:4151767 [0] NCCL INFO + PCI[24.0] - GPU/E00000 (1)
# node-0:4149074:4151767 [0] NCCL INFO               + XGMI[144.0] - GPU/D00000
# node-0:4149074:4151767 [0] NCCL INFO               + XGMI[36.0] - GPU/F00000
# node-0:4149074:4151767 [0] NCCL INFO               + XGMI[36.0] - GPU/1000000
# node-0:4149074:4151767 [0] NCCL INFO + PCI[24.0] - GPU/F00000 (2)
# node-0:4149074:4151767 [0] NCCL INFO               + XGMI[144.0] - GPU/1000000
# node-0:4149074:4151767 [0] NCCL INFO               + XGMI[36.0] - GPU/D00000
# node-0:4149074:4151767 [0] NCCL INFO               + XGMI[36.0] - GPU/E00000
# node-0:4149074:4151767 [0] NCCL INFO + PCI[24.0] - GPU/1000000 (3)
# node-0:4149074:4151767 [0] NCCL INFO               + XGMI[144.0] - GPU/F00000
# node-0:4149074:4151767 [0] NCCL INFO               + XGMI[36.0] - GPU/E00000
# node-0:4149074:4151767 [0] NCCL INFO ==========================================
# node-0:4149074:4151767 [0] NCCL INFO GPU/D00000 :GPU/D00000 (0/5000.000000/LOC) GPU/E00000 (1/144.000000/XGMI) GPU/F00000 (1/36.000000/XGMI) GPU/1000000 (2/24.000000/PHB) CPU/2 (1/24.000000/PHB)
# node-0:4149074:4151767 [0] NCCL INFO GPU/E00000 :GPU/D00000 (1/144.000000/XGMI) GPU/E00000 (0/5000.000000/LOC) GPU/F00000 (1/36.000000/XGMI) GPU/1000000 (1/36.000000/XGMI) CPU/2 (1/24.000000/PHB)
# node-0:4149074:4151767 [0] NCCL INFO GPU/F00000 :GPU/D00000 (1/36.000000/XGMI) GPU/E00000 (1/36.000000/XGMI) GPU/F00000 (0/5000.000000/LOC) GPU/1000000 (1/144.000000/XGMI) CPU/2 (1/24.000000/PHB)
# node-0:4149074:4151767 [0] NCCL INFO GPU/1000000 :GPU/D00000 (2/24.000000/PHB) GPU/E00000 (1/36.000000/XGMI) GPU/F00000 (1/144.000000/XGMI) GPU/1000000 (0/5000.000000/LOC) CPU/2 (1/24.000000/PHB)
# node-0:4149074:4151767 [0] NCCL INFO Setting affinity for GPU 12 to ff,ffff0000,00000000
# node-0:4149074:4151769 [2] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-0010-0000-3130-303237343043/pci0010:00/0010:00:00.0/../max_link_width, ignoring
# node-0:4149074:4151771 [3] NCCL INFO === System : maxBw 144.0 totalBw 216.0 ===
# node-0:4149074:4151771 [3] NCCL INFO CPU/2 (1/2/4)
# node-0:4149074:4151771 [3] NCCL INFO + PCI[5000.0] - NIC/0
# node-0:4149074:4151771 [3] NCCL INFO + PCI[24.0] - GPU/D00000 (0)
# node-0:4149074:4151771 [3] NCCL INFO               + XGMI[144.0] - GPU/E00000
# node-0:4149074:4151771 [3] NCCL INFO               + XGMI[36.0] - GPU/F00000
# node-0:4149074:4151771 [3] NCCL INFO + PCI[24.0] - GPU/E00000 (1)
# node-0:4149074:4151771 [3] NCCL INFO               + XGMI[144.0] - GPU/D00000
# node-0:4149074:4151771 [3] NCCL INFO               + XGMI[36.0] - GPU/F00000
# node-0:4149074:4151771 [3] NCCL INFO               + XGMI[36.0] - GPU/1000000
# node-0:4149074:4151771 [3] NCCL INFO + PCI[24.0] - GPU/F00000 (2)
# node-0:4149074:4151771 [3] NCCL INFO               + XGMI[144.0] - GPU/1000000
# node-0:4149074:4151771 [3] NCCL INFO               + XGMI[36.0] - GPU/D00000
# node-0:4149074:4151771 [3] NCCL INFO               + XGMI[36.0] - GPU/E00000
# node-0:4149074:4151771 [3] NCCL INFO + PCI[24.0] - GPU/1000000 (3)
# node-0:4149074:4151771 [3] NCCL INFO               + XGMI[144.0] - GPU/F00000
# node-0:4149074:4151771 [3] NCCL INFO               + XGMI[36.0] - GPU/E00000
# node-0:4149074:4151771 [3] NCCL INFO ==========================================
# node-0:4149074:4151771 [3] NCCL INFO GPU/D00000 :GPU/D00000 (0/5000.000000/LOC) GPU/E00000 (1/144.000000/XGMI) GPU/F00000 (1/36.000000/XGMI) GPU/1000000 (2/24.000000/PHB) CPU/2 (1/24.000000/PHB)
# node-0:4149074:4151771 [3] NCCL INFO GPU/E00000 :GPU/D00000 (1/144.000000/XGMI) GPU/E00000 (0/5000.000000/LOC) GPU/F00000 (1/36.000000/XGMI) GPU/1000000 (1/36.000000/XGMI) CPU/2 (1/24.000000/PHB)
# node-0:4149074:4151771 [3] NCCL INFO GPU/F00000 :GPU/D00000 (1/36.000000/XGMI) GPU/E00000 (1/36.000000/XGMI) GPU/F00000 (0/5000.000000/LOC) GPU/1000000 (1/144.000000/XGMI) CPU/2 (1/24.000000/PHB)
# node-0:4149074:4151771 [3] NCCL INFO GPU/1000000 :GPU/D00000 (2/24.000000/PHB) GPU/E00000 (1/36.000000/XGMI) GPU/F00000 (1/144.000000/XGMI) GPU/1000000 (0/5000.000000/LOC) CPU/2 (1/24.000000/PHB)
# node-0:4149074:4151768 [1] NCCL INFO Topology detection : could not read /sys/devices/LNXSYSTM:00/LNXSYBUS:00/ACPI0004:00/VMBUS:00/47505500-0010-0000-3130-303237343043/pci0010:00/0010:00:00.0/../max_link_width, ignoring
# node-0:4149074:4151771 [3] NCCL INFO Setting affinity for GPU 15 to ff,ffff0000,00000000
# node-0:4149074:4151769 [2] NCCL INFO === System : maxBw 144.0 totalBw 216.0 ===
# node-0:4149074:4151769 [2] NCCL INFO CPU/2 (1/2/4)
# node-0:4149074:4151769 [2] NCCL INFO + PCI[5000.0] - NIC/0
# node-0:4149074:4151769 [2] NCCL INFO + PCI[24.0] - GPU/D00000 (0)
# node-0:4149074:4151769 [2] NCCL INFO               + XGMI[144.0] - GPU/E00000
# node-0:4149074:4151769 [2] NCCL INFO               + XGMI[36.0] - GPU/F00000
# node-0:4149074:4151769 [2] NCCL INFO + PCI[24.0] - GPU/E00000 (1)
# node-0:4149074:4151769 [2] NCCL INFO               + XGMI[144.0] - GPU/D00000
# node-0:4149074:4151769 [2] NCCL INFO               + XGMI[36.0] - GPU/F00000
# node-0:4149074:4151769 [2] NCCL INFO               + XGMI[36.0] - GPU/1000000
# node-0:4149074:4151769 [2] NCCL INFO + PCI[24.0] - GPU/F00000 (2)
# node-0:4149074:4151769 [2] NCCL INFO               + XGMI[144.0] - GPU/1000000
# node-0:4149074:4151769 [2] NCCL INFO               + XGMI[36.0] - GPU/D00000
# node-0:4149074:4151769 [2] NCCL INFO               + XGMI[36.0] - GPU/E00000
# node-0:4149074:4151769 [2] NCCL INFO + PCI[24.0] - GPU/1000000 (3)
# node-0:4149074:4151769 [2] NCCL INFO               + XGMI[144.0] - GPU/F00000
# node-0:4149074:4151769 [2] NCCL INFO               + XGMI[36.0] - GPU/E00000
# node-0:4149074:4151769 [2] NCCL INFO ==========================================
# node-0:4149074:4151769 [2] NCCL INFO GPU/D00000 :GPU/D00000 (0/5000.000000/LOC) GPU/E00000 (1/144.000000/XGMI) GPU/F00000 (1/36.000000/XGMI) GPU/1000000 (2/24.000000/PHB) CPU/2 (1/24.000000/PHB)
# node-0:4149074:4151768 [1] NCCL INFO === System : maxBw 144.0 totalBw 216.0 ===
# node-0:4149074:4151768 [1] NCCL INFO CPU/2 (1/2/4)
# node-0:4149074:4151769 [2] NCCL INFO GPU/E00000 :GPU/D00000 (1/144.000000/XGMI) GPU/E00000 (0/5000.000000/LOC) GPU/F00000 (1/36.000000/XGMI) GPU/1000000 (1/36.000000/XGMI) CPU/2 (1/24.000000/PHB)
# node-0:4149074:4151768 [1] NCCL INFO + PCI[5000.0] - NIC/0
# node-0:4149074:4151768 [1] NCCL INFO + PCI[24.0] - GPU/D00000 (0)
# node-0:4149074:4151768 [1] NCCL INFO               + XGMI[144.0] - GPU/E00000
# node-0:4149074:4151769 [2] NCCL INFO GPU/F00000 :GPU/D00000 (1/36.000000/XGMI) GPU/E00000 (1/36.000000/XGMI) GPU/F00000 (0/5000.000000/LOC) GPU/1000000 (1/144.000000/XGMI) CPU/2 (1/24.000000/PHB)
# node-0:4149074:4151768 [1] NCCL INFO               + XGMI[36.0] - GPU/F00000
# node-0:4149074:4151768 [1] NCCL INFO + PCI[24.0] - GPU/E00000 (1)
# node-0:4149074:4151768 [1] NCCL INFO               + XGMI[144.0] - GPU/D00000
# node-0:4149074:4151768 [1] NCCL INFO               + XGMI[36.0] - GPU/F00000
# node-0:4149074:4151768 [1] NCCL INFO               + XGMI[36.0] - GPU/1000000
# node-0:4149074:4151768 [1] NCCL INFO + PCI[24.0] - GPU/F00000 (2)
# node-0:4149074:4151768 [1] NCCL INFO               + XGMI[144.0] - GPU/1000000
# node-0:4149074:4151768 [1] NCCL INFO               + XGMI[36.0] - GPU/D00000
# node-0:4149074:4151768 [1] NCCL INFO               + XGMI[36.0] - GPU/E00000
# node-0:4149074:4151769 [2] NCCL INFO GPU/1000000 :GPU/D00000 (2/24.000000/PHB) GPU/E00000 (1/36.000000/XGMI) GPU/F00000 (1/144.000000/XGMI) GPU/1000000 (0/5000.000000/LOC) CPU/2 (1/24.000000/PHB)
# node-0:4149074:4151768 [1] NCCL INFO + PCI[24.0] - GPU/1000000 (3)
# node-0:4149074:4151768 [1] NCCL INFO               + XGMI[144.0] - GPU/F00000
# node-0:4149074:4151768 [1] NCCL INFO               + XGMI[36.0] - GPU/E00000
# node-0:4149074:4151768 [1] NCCL INFO ==========================================
# node-0:4149074:4151769 [2] NCCL INFO Setting affinity for GPU 14 to ff,ffff0000,00000000
# node-0:4149074:4151768 [1] NCCL INFO GPU/D00000 :GPU/D00000 (0/5000.000000/LOC) GPU/E00000 (1/144.000000/XGMI) GPU/F00000 (1/36.000000/XGMI) GPU/1000000 (2/24.000000/PHB) CPU/2 (1/24.000000/PHB)
# node-0:4149074:4151768 [1] NCCL INFO GPU/E00000 :GPU/D00000 (1/144.000000/XGMI) GPU/E00000 (0/5000.000000/LOC) GPU/F00000 (1/36.000000/XGMI) GPU/1000000 (1/36.000000/XGMI) CPU/2 (1/24.000000/PHB)
# node-0:4149074:4151768 [1] NCCL INFO GPU/F00000 :GPU/D00000 (1/36.000000/XGMI) GPU/E00000 (1/36.000000/XGMI) GPU/F00000 (0/5000.000000/LOC) GPU/1000000 (1/144.000000/XGMI) CPU/2 (1/24.000000/PHB)
# node-0:4149074:4151768 [1] NCCL INFO GPU/1000000 :GPU/D00000 (2/24.000000/PHB) GPU/E00000 (1/36.000000/XGMI) GPU/F00000 (1/144.000000/XGMI) GPU/1000000 (0/5000.000000/LOC) CPU/2 (1/24.000000/PHB)
# node-0:4149074:4151768 [1] NCCL INFO Setting affinity for GPU 13 to ff,ffff0000,00000000
# node-0:4149074:4151767 [0] NCCL INFO Pattern 4, crossNic 0, nChannels 4, bw 18.000000/18.000000, type XGMI/PIX, sameChannels 0
# node-0:4149074:4151767 [0] NCCL INFO  0 : GPU/0 GPU/1 GPU/3 GPU/2
# node-0:4149074:4151767 [0] NCCL INFO  1 : GPU/0 GPU/1 GPU/3 GPU/2
# node-0:4149074:4151767 [0] NCCL INFO  2 : GPU/0 GPU/2 GPU/3 GPU/1
# node-0:4149074:4151767 [0] NCCL INFO  3 : GPU/0 GPU/2 GPU/3 GPU/1
# node-0:4149074:4151767 [0] NCCL INFO Pattern 1, crossNic 0, nChannels 4, bw 24.000000/24.000000, type XGMI/PIX, sameChannels 0
# node-0:4149074:4151767 [0] NCCL INFO  0 : GPU/0 GPU/1 GPU/2 GPU/3
# node-0:4149074:4151767 [0] NCCL INFO  1 : GPU/0 GPU/1 GPU/3 GPU/2
# node-0:4149074:4151767 [0] NCCL INFO  2 : GPU/0 GPU/2 GPU/3 GPU/1
# node-0:4149074:4151767 [0] NCCL INFO  3 : GPU/3 GPU/2 GPU/0 GPU/1
# node-0:4149074:4151771 [3] NCCL INFO Pattern 4, crossNic 0, nChannels 4, bw 18.000000/18.000000, type XGMI/PIX, sameChannels 0
# node-0:4149074:4151771 [3] NCCL INFO  0 : GPU/0 GPU/1 GPU/3 GPU/2
# node-0:4149074:4151771 [3] NCCL INFO  1 : GPU/0 GPU/1 GPU/3 GPU/2
# node-0:4149074:4151771 [3] NCCL INFO  2 : GPU/0 GPU/2 GPU/3 GPU/1
# node-0:4149074:4151771 [3] NCCL INFO  3 : GPU/0 GPU/2 GPU/3 GPU/1
# node-0:4149074:4151771 [3] NCCL INFO Pattern 1, crossNic 0, nChannels 4, bw 24.000000/24.000000, type XGMI/PIX, sameChannels 0
# node-0:4149074:4151771 [3] NCCL INFO  0 : GPU/0 GPU/1 GPU/2 GPU/3
# node-0:4149074:4151771 [3] NCCL INFO  1 : GPU/0 GPU/1 GPU/3 GPU/2
# node-0:4149074:4151771 [3] NCCL INFO  2 : GPU/0 GPU/2 GPU/3 GPU/1
# node-0:4149074:4151771 [3] NCCL INFO  3 : GPU/3 GPU/2 GPU/0 GPU/1
# node-0:4149074:4151767 [0] NCCL INFO Pattern 3, crossNic 0, nChannels 4, bw 24.000000/24.000000, type XGMI/PIX, sameChannels 0
# node-0:4149074:4151767 [0] NCCL INFO  0 : GPU/0 GPU/1 GPU/2 GPU/3
# node-0:4149074:4151767 [0] NCCL INFO  1 : GPU/0 GPU/1 GPU/3 GPU/2
# node-0:4149074:4151767 [0] NCCL INFO  2 : GPU/0 GPU/2 GPU/3 GPU/1
# node-0:4149074:4151767 [0] NCCL INFO  3 : GPU/3 GPU/2 GPU/0 GPU/1
# node-0:4149074:4151771 [3] NCCL INFO Pattern 3, crossNic 0, nChannels 4, bw 24.000000/24.000000, type XGMI/PIX, sameChannels 0
# node-0:4149074:4151771 [3] NCCL INFO  0 : GPU/0 GPU/1 GPU/2 GPU/3
# node-0:4149074:4151771 [3] NCCL INFO  1 : GPU/0 GPU/1 GPU/3 GPU/2
# node-0:4149074:4151771 [3] NCCL INFO  2 : GPU/0 GPU/2 GPU/3 GPU/1
# node-0:4149074:4151771 [3] NCCL INFO  3 : GPU/3 GPU/2 GPU/0 GPU/1
# node-0:4149074:4151769 [2] NCCL INFO Pattern 4, crossNic 0, nChannels 4, bw 18.000000/18.000000, type XGMI/PIX, sameChannels 0
# node-0:4149074:4151769 [2] NCCL INFO  0 : GPU/0 GPU/1 GPU/3 GPU/2
# node-0:4149074:4151769 [2] NCCL INFO  1 : GPU/0 GPU/1 GPU/3 GPU/2
# node-0:4149074:4151769 [2] NCCL INFO  2 : GPU/0 GPU/2 GPU/3 GPU/1
# node-0:4149074:4151769 [2] NCCL INFO  3 : GPU/0 GPU/2 GPU/3 GPU/1
# node-0:4149074:4151768 [1] NCCL INFO Pattern 4, crossNic 0, nChannels 4, bw 18.000000/18.000000, type XGMI/PIX, sameChannels 0
# node-0:4149074:4151768 [1] NCCL INFO  0 : GPU/0 GPU/1 GPU/3 GPU/2
# node-0:4149074:4151768 [1] NCCL INFO  1 : GPU/0 GPU/1 GPU/3 GPU/2
# node-0:4149074:4151768 [1] NCCL INFO  2 : GPU/0 GPU/2 GPU/3 GPU/1
# node-0:4149074:4151768 [1] NCCL INFO  3 : GPU/0 GPU/2 GPU/3 GPU/1
# node-0:4149074:4151769 [2] NCCL INFO Pattern 1, crossNic 0, nChannels 4, bw 24.000000/24.000000, type XGMI/PIX, sameChannels 0
# node-0:4149074:4151769 [2] NCCL INFO  0 : GPU/0 GPU/1 GPU/2 GPU/3
# node-0:4149074:4151769 [2] NCCL INFO  1 : GPU/0 GPU/1 GPU/3 GPU/2
# node-0:4149074:4151769 [2] NCCL INFO  2 : GPU/0 GPU/2 GPU/3 GPU/1
# node-0:4149074:4151769 [2] NCCL INFO  3 : GPU/3 GPU/2 GPU/0 GPU/1
# node-0:4149074:4151768 [1] NCCL INFO Pattern 1, crossNic 0, nChannels 4, bw 24.000000/24.000000, type XGMI/PIX, sameChannels 0
# node-0:4149074:4151768 [1] NCCL INFO  0 : GPU/0 GPU/1 GPU/2 GPU/3
# node-0:4149074:4151768 [1] NCCL INFO  1 : GPU/0 GPU/1 GPU/3 GPU/2
# node-0:4149074:4151768 [1] NCCL INFO  2 : GPU/0 GPU/2 GPU/3 GPU/1
# node-0:4149074:4151768 [1] NCCL INFO  3 : GPU/3 GPU/2 GPU/0 GPU/1
# node-0:4149074:4151769 [2] NCCL INFO Pattern 3, crossNic 0, nChannels 4, bw 24.000000/24.000000, type XGMI/PIX, sameChannels 0
# node-0:4149074:4151769 [2] NCCL INFO  0 : GPU/0 GPU/1 GPU/2 GPU/3
# node-0:4149074:4151769 [2] NCCL INFO  1 : GPU/0 GPU/1 GPU/3 GPU/2
# node-0:4149074:4151769 [2] NCCL INFO  2 : GPU/0 GPU/2 GPU/3 GPU/1
# node-0:4149074:4151769 [2] NCCL INFO  3 : GPU/3 GPU/2 GPU/0 GPU/1
# node-0:4149074:4151768 [1] NCCL INFO Pattern 3, crossNic 0, nChannels 4, bw 24.000000/24.000000, type XGMI/PIX, sameChannels 0
# node-0:4149074:4151768 [1] NCCL INFO  0 : GPU/0 GPU/1 GPU/2 GPU/3
# node-0:4149074:4151768 [1] NCCL INFO  1 : GPU/0 GPU/1 GPU/3 GPU/2
# node-0:4149074:4151768 [1] NCCL INFO  2 : GPU/0 GPU/2 GPU/3 GPU/1
# node-0:4149074:4151768 [1] NCCL INFO  3 : GPU/3 GPU/2 GPU/0 GPU/1
# node-0:4149074:4151767 [0] NCCL INFO Tree 0 : -1 -> 0 -> 1/-1/-1
# node-0:4149074:4151767 [0] NCCL INFO Tree 4 : -1 -> 0 -> 1/-1/-1
# node-0:4149074:4151767 [0] NCCL INFO Tree 1 : -1 -> 0 -> 1/-1/-1
# node-0:4149074:4151767 [0] NCCL INFO Tree 5 : -1 -> 0 -> 1/-1/-1
# node-0:4149074:4151767 [0] NCCL INFO Tree 2 : -1 -> 0 -> 2/-1/-1
# node-0:4149074:4151767 [0] NCCL INFO Tree 6 : -1 -> 0 -> 2/-1/-1
# node-0:4149074:4151771 [3] NCCL INFO Tree 3 : -1 -> 3 -> 2/-1/-1
# node-0:4149074:4151767 [0] NCCL INFO Channel 00/16 :    0   1   3   2
# node-0:4149074:4151767 [0] NCCL INFO Channel 01/16 :    0   1   3   2
# node-0:4149074:4151767 [0] NCCL INFO Channel 02/16 :    0   2   3   1
# node-0:4149074:4151767 [0] NCCL INFO Channel 03/16 :    0   2   3   1
# node-0:4149074:4151771 [3] NCCL INFO Tree 7 : -1 -> 3 -> 2/-1/-1
# node-0:4149074:4151767 [0] NCCL INFO Channel 04/16 :    0   1   3   2
# node-0:4149074:4151767 [0] NCCL INFO Channel 05/16 :    0   1   3   2
# node-0:4149074:4151767 [0] NCCL INFO Channel 06/16 :    0   2   3   1
# node-0:4149074:4151767 [0] NCCL INFO Channel 07/16 :    0   2   3   1
# node-0:4149074:4151767 [0] NCCL INFO Channel 08/16 :    0   1   3   2
# node-0:4149074:4151767 [0] NCCL INFO Channel 09/16 :    0   1   3   2
# node-0:4149074:4151767 [0] NCCL INFO Channel 10/16 :    0   2   3   1
# node-0:4149074:4151771 [3] NCCL INFO Ring 0 : 1 -> 3 -> 2 comm 0x11e226c0 nRanks 04 busId 1000000
# node-0:4149074:4151768 [1] NCCL INFO Tree 0 : 0 -> 1 -> 2/-1/-1
# node-0:4149074:4151771 [3] NCCL INFO Ring 1 : 1 -> 3 -> 2 comm 0x11e226c0 nRanks 04 busId 1000000
# node-0:4149074:4151771 [3] NCCL INFO Ring 2 : 2 -> 3 -> 1 comm 0x11e226c0 nRanks 04 busId 1000000
# node-0:4149074:4151768 [1] NCCL INFO Tree 4 : 0 -> 1 -> 2/-1/-1
# node-0:4149074:4151771 [3] NCCL INFO Ring 3 : 2 -> 3 -> 1 comm 0x11e226c0 nRanks 04 busId 1000000
# node-0:4149074:4151768 [1] NCCL INFO Tree 1 : 0 -> 1 -> 3/-1/-1
# node-0:4149074:4151768 [1] NCCL INFO Tree 5 : 0 -> 1 -> 3/-1/-1
# node-0:4149074:4151771 [3] NCCL INFO Ring 4 : 1 -> 3 -> 2 comm 0x11e226c0 nRanks 04 busId 1000000
# node-0:4149074:4151771 [3] NCCL INFO Ring 5 : 1 -> 3 -> 2 comm 0x11e226c0 nRanks 04 busId 1000000
# node-0:4149074:4151771 [3] NCCL INFO Ring 6 : 2 -> 3 -> 1 comm 0x11e226c0 nRanks 04 busId 1000000
# node-0:4149074:4151771 [3] NCCL INFO Ring 7 : 2 -> 3 -> 1 comm 0x11e226c0 nRanks 04 busId 1000000
# node-0:4149074:4151769 [2] NCCL INFO Tree 2 : 0 -> 2 -> 3/-1/-1
# node-0:4149074:4151771 [3] NCCL INFO Ring 8 : 1 -> 3 -> 2 comm 0x11e226c0 nRanks 04 busId 1000000
# node-0:4149074:4151767 [0] NCCL INFO Channel 11/16 :    0   2   3   1
# node-0:4149074:4151768 [1] NCCL INFO Ring 0 : 0 -> 1 -> 3 comm 0xee1b730 nRanks 04 busId e00000
# node-0:4149074:4151771 [3] NCCL INFO Ring 9 : 1 -> 3 -> 2 comm 0x11e226c0 nRanks 04 busId 1000000
# node-0:4149074:4151767 [0] NCCL INFO Channel 12/16 :    0   1   3   2
# node-0:4149074:4151769 [2] NCCL INFO Tree 6 : 0 -> 2 -> 3/-1/-1
# node-0:4149074:4151768 [1] NCCL INFO Ring 1 : 0 -> 1 -> 3 comm 0xee1b730 nRanks 04 busId e00000
# node-0:4149074:4151767 [0] NCCL INFO Channel 13/16 :    0   1   3   2
# node-0:4149074:4151771 [3] NCCL INFO Ring 10 : 2 -> 3 -> 1 comm 0x11e226c0 nRanks 04 busId 1000000
# node-0:4149074:4151769 [2] NCCL INFO Tree 3 : 3 -> 2 -> 0/-1/-1
# node-0:4149074:4151767 [0] NCCL INFO Channel 14/16 :    0   2   3   1
# node-0:4149074:4151768 [1] NCCL INFO Ring 2 : 3 -> 1 -> 0 comm 0xee1b730 nRanks 04 busId e00000
# node-0:4149074:4151771 [3] NCCL INFO Ring 11 : 2 -> 3 -> 1 comm 0x11e226c0 nRanks 04 busId 1000000
# node-0:4149074:4151769 [2] NCCL INFO Tree 7 : 3 -> 2 -> 0/-1/-1
# node-0:4149074:4151767 [0] NCCL INFO Channel 15/16 :    0   2   3   1
# node-0:4149074:4151768 [1] NCCL INFO Ring 3 : 3 -> 1 -> 0 comm 0xee1b730 nRanks 04 busId e00000
# node-0:4149074:4151767 [0] NCCL INFO Ring 0 : 2 -> 0 -> 1 comm 0x106325f0 nRanks 04 busId d00000
# node-0:4149074:4151767 [0] NCCL INFO Ring 1 : 2 -> 0 -> 1 comm 0x106325f0 nRanks 04 busId d00000
# node-0:4149074:4151767 [0] NCCL INFO Ring 2 : 1 -> 0 -> 2 comm 0x106325f0 nRanks 04 busId d00000
# node-0:4149074:4151769 [2] NCCL INFO Ring 0 : 3 -> 2 -> 0 comm 0x106f7dd0 nRanks 04 busId f00000
# node-0:4149074:4151767 [0] NCCL INFO Ring 3 : 1 -> 0 -> 2 comm 0x106325f0 nRanks 04 busId d00000
# node-0:4149074:4151767 [0] NCCL INFO Ring 4 : 2 -> 0 -> 1 comm 0x106325f0 nRanks 04 busId d00000
# node-0:4149074:4151767 [0] NCCL INFO Ring 5 : 2 -> 0 -> 1 comm 0x106325f0 nRanks 04 busId d00000
# node-0:4149074:4151771 [3] NCCL INFO Ring 12 : 1 -> 3 -> 2 comm 0x11e226c0 nRanks 04 busId 1000000
# node-0:4149074:4151769 [2] NCCL INFO Ring 1 : 3 -> 2 -> 0 comm 0x106f7dd0 nRanks 04 busId f00000
# node-0:4149074:4151767 [0] NCCL INFO Ring 6 : 1 -> 0 -> 2 comm 0x106325f0 nRanks 04 busId d00000
# node-0:4149074:4151771 [3] NCCL INFO Ring 13 : 1 -> 3 -> 2 comm 0x11e226c0 nRanks 04 busId 1000000
# node-0:4149074:4151769 [2] NCCL INFO Ring 2 : 0 -> 2 -> 3 comm 0x106f7dd0 nRanks 04 busId f00000
# node-0:4149074:4151767 [0] NCCL INFO Ring 7 : 1 -> 0 -> 2 comm 0x106325f0 nRanks 04 busId d00000
# node-0:4149074:4151771 [3] NCCL INFO Ring 14 : 2 -> 3 -> 1 comm 0x11e226c0 nRanks 04 busId 1000000
# node-0:4149074:4151769 [2] NCCL INFO Ring 3 : 0 -> 2 -> 3 comm 0x106f7dd0 nRanks 04 busId f00000
# node-0:4149074:4151771 [3] NCCL INFO Ring 15 : 2 -> 3 -> 1 comm 0x11e226c0 nRanks 04 busId 1000000
# node-0:4149074:4151769 [2] NCCL INFO Ring 4 : 3 -> 2 -> 0 comm 0x106f7dd0 nRanks 04 busId f00000
# node-0:4149074:4151771 [3] NCCL INFO Trees [0] -1/-1/-1->3->2 [1] 2/-1/-1->3->1 [2] 1/-1/-1->3->2 [3] 2/-1/-1->3->-1 [4] -1/-1/-1->3->2 [5] 2/-1/-1->3->1 [6] 1/-1/-1->3->2 [7] 2/-1/-1->3->-1 [8] -1/-1/-1->3->2 [9] 2/-1/-1->3->1 [10] 1/-1/-1->3->2 [11] 2/-1/-1->3->-1 [12] -1/-1/-1->3->2 [13] 2/-1/-1->3->1 [14] 1/-1/-1->3->2 [15] 2/-1/-1->3->-1 comm 0x11e226c0 nRanks 04 busId 1000000
# node-0:4149074:4151769 [2] NCCL INFO Ring 5 : 3 -> 2 -> 0 comm 0x106f7dd0 nRanks 04 busId f00000
# node-0:4149074:4151768 [1] NCCL INFO Ring 4 : 0 -> 1 -> 3 comm 0xee1b730 nRanks 04 busId e00000
# node-0:4149074:4151769 [2] NCCL INFO Ring 6 : 0 -> 2 -> 3 comm 0x106f7dd0 nRanks 04 busId f00000
# node-0:4149074:4151768 [1] NCCL INFO Ring 5 : 0 -> 1 -> 3 comm 0xee1b730 nRanks 04 busId e00000
# node-0:4149074:4151769 [2] NCCL INFO Ring 7 : 0 -> 2 -> 3 comm 0x106f7dd0 nRanks 04 busId f00000
# node-0:4149074:4151768 [1] NCCL INFO Ring 6 : 3 -> 1 -> 0 comm 0xee1b730 nRanks 04 busId e00000
# node-0:4149074:4151771 [3] NCCL INFO P2P Chunksize set to 524288
# node-0:4149074:4151769 [2] NCCL INFO Ring 8 : 3 -> 2 -> 0 comm 0x106f7dd0 nRanks 04 busId f00000
# node-0:4149074:4151768 [1] NCCL INFO Ring 7 : 3 -> 1 -> 0 comm 0xee1b730 nRanks 04 busId e00000
# node-0:4149074:4151768 [1] NCCL INFO Ring 8 : 0 -> 1 -> 3 comm 0xee1b730 nRanks 04 busId e00000
# node-0:4149074:4151768 [1] NCCL INFO Ring 9 : 0 -> 1 -> 3 comm 0xee1b730 nRanks 04 busId e00000
# node-0:4149074:4151768 [1] NCCL INFO Ring 10 : 3 -> 1 -> 0 comm 0xee1b730 nRanks 04 busId e00000
# node-0:4149074:4151769 [2] NCCL INFO Ring 9 : 3 -> 2 -> 0 comm 0x106f7dd0 nRanks 04 busId f00000
# node-0:4149074:4151768 [1] NCCL INFO Ring 11 : 3 -> 1 -> 0 comm 0xee1b730 nRanks 04 busId e00000
# node-0:4149074:4151769 [2] NCCL INFO Ring 10 : 0 -> 2 -> 3 comm 0x106f7dd0 nRanks 04 busId f00000
# node-0:4149074:4151768 [1] NCCL INFO Ring 12 : 0 -> 1 -> 3 comm 0xee1b730 nRanks 04 busId e00000
# node-0:4149074:4151767 [0] NCCL INFO Ring 8 : 2 -> 0 -> 1 comm 0x106325f0 nRanks 04 busId d00000
# node-0:4149074:4151769 [2] NCCL INFO Ring 11 : 0 -> 2 -> 3 comm 0x106f7dd0 nRanks 04 busId f00000
# node-0:4149074:4151768 [1] NCCL INFO Ring 13 : 0 -> 1 -> 3 comm 0xee1b730 nRanks 04 busId e00000
# node-0:4149074:4151769 [2] NCCL INFO Ring 12 : 3 -> 2 -> 0 comm 0x106f7dd0 nRanks 04 busId f00000
# node-0:4149074:4151768 [1] NCCL INFO Ring 14 : 3 -> 1 -> 0 comm 0xee1b730 nRanks 04 busId e00000
# node-0:4149074:4151767 [0] NCCL INFO Ring 9 : 2 -> 0 -> 1 comm 0x106325f0 nRanks 04 busId d00000
# node-0:4149074:4151769 [2] NCCL INFO Ring 13 : 3 -> 2 -> 0 comm 0x106f7dd0 nRanks 04 busId f00000
# node-0:4149074:4151768 [1] NCCL INFO Ring 15 : 3 -> 1 -> 0 comm 0xee1b730 nRanks 04 busId e00000
# node-0:4149074:4151767 [0] NCCL INFO Ring 10 : 1 -> 0 -> 2 comm 0x106325f0 nRanks 04 busId d00000
# node-0:4149074:4151769 [2] NCCL INFO Ring 14 : 0 -> 2 -> 3 comm 0x106f7dd0 nRanks 04 busId f00000
# node-0:4149074:4151768 [1] NCCL INFO Trees [0] 2/-1/-1->1->0 [1] 3/-1/-1->1->0 [2] -1/-1/-1->1->3 [3] -1/-1/-1->1->0 [4] 2/-1/-1->1->0 [5] 3/-1/-1->1->0 [6] -1/-1/-1->1->3 [7] -1/-1/-1->1->0 [8] 2/-1/-1->1->0 [9] 3/-1/-1->1->0 [10] -1/-1/-1->1->3 [11] -1/-1/-1->1->0 [12] 2/-1/-1->1->0 [13] 3/-1/-1->1->0 [14] -1/-1/-1->1->3 [15] -1/-1/-1->1->0 comm 0xee1b730 nRanks 04 busId e00000
# node-0:4149074:4151768 [1] NCCL INFO P2P Chunksize set to 524288
# node-0:4149074:4151767 [0] NCCL INFO Ring 11 : 1 -> 0 -> 2 comm 0x106325f0 nRanks 04 busId d00000
# node-0:4149074:4151769 [2] NCCL INFO Ring 15 : 0 -> 2 -> 3 comm 0x106f7dd0 nRanks 04 busId f00000
# node-0:4149074:4151767 [0] NCCL INFO Ring 12 : 2 -> 0 -> 1 comm 0x106325f0 nRanks 04 busId d00000
# node-0:4149074:4151769 [2] NCCL INFO Trees [0] 3/-1/-1->2->1 [1] -1/-1/-1->2->3 [2] 3/-1/-1->2->0 [3] 0/-1/-1->2->3 [4] 3/-1/-1->2->1 [5] -1/-1/-1->2->3 [6] 3/-1/-1->2->0 [7] 0/-1/-1->2->3 [8] 3/-1/-1->2->1 [9] -1/-1/-1->2->3 [10] 3/-1/-1->2->0 [11] 0/-1/-1->2->3 [12] 3/-1/-1->2->1 [13] -1/-1/-1->2->3 [14] 3/-1/-1->2->0 [15] 0/-1/-1->2->3 comm 0x106f7dd0 nRanks 04 busId f00000
# node-0:4149074:4151767 [0] NCCL INFO Ring 13 : 2 -> 0 -> 1 comm 0x106325f0 nRanks 04 busId d00000
# node-0:4149074:4151769 [2] NCCL INFO P2P Chunksize set to 524288
# node-0:4149074:4151767 [0] NCCL INFO Ring 14 : 1 -> 0 -> 2 comm 0x106325f0 nRanks 04 busId d00000
# node-0:4149074:4151767 [0] NCCL INFO Ring 15 : 1 -> 0 -> 2 comm 0x106325f0 nRanks 04 busId d00000
# node-0:4149074:4151767 [0] NCCL INFO Trees [0] 1/-1/-1->0->-1 [1] 1/-1/-1->0->-1 [2] 2/-1/-1->0->-1 [3] 1/-1/-1->0->2 [4] 1/-1/-1->0->-1 [5] 1/-1/-1->0->-1 [6] 2/-1/-1->0->-1 [7] 1/-1/-1->0->2 [8] 1/-1/-1->0->-1 [9] 1/-1/-1->0->-1 [10] 2/-1/-1->0->-1 [11] 1/-1/-1->0->2 [12] 1/-1/-1->0->-1 [13] 1/-1/-1->0->-1 [14] 2/-1/-1->0->-1 [15] 1/-1/-1->0->2 comm 0x106325f0 nRanks 04 busId d00000
# node-0:4149074:4151767 [0] NCCL INFO P2P Chunksize set to 524288
# node-0:4149074:4151767 [0] NCCL INFO Channel 00/0 : 0[d00000] -> 1[e00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 02/0 : 2[f00000] -> 3[1000000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151767 [0] NCCL INFO Channel 01/0 : 0[d00000] -> 1[e00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 03/0 : 2[f00000] -> 3[1000000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151767 [0] NCCL INFO Channel 04/0 : 0[d00000] -> 1[e00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 06/0 : 2[f00000] -> 3[1000000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151767 [0] NCCL INFO Channel 05/0 : 0[d00000] -> 1[e00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 07/0 : 2[f00000] -> 3[1000000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151767 [0] NCCL INFO Channel 08/0 : 0[d00000] -> 1[e00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 10/0 : 2[f00000] -> 3[1000000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151767 [0] NCCL INFO Channel 09/0 : 0[d00000] -> 1[e00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 11/0 : 2[f00000] -> 3[1000000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151767 [0] NCCL INFO Channel 12/0 : 0[d00000] -> 1[e00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 14/0 : 2[f00000] -> 3[1000000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 15/0 : 2[f00000] -> 3[1000000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151767 [0] NCCL INFO Channel 13/0 : 0[d00000] -> 1[e00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 00/0 : 1[e00000] -> 3[1000000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 02/0 : 3[1000000] -> 1[e00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151767 [0] NCCL INFO Channel 02/0 : 0[d00000] -> 2[f00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 00/0 : 2[f00000] -> 0[d00000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 01/0 : 1[e00000] -> 3[1000000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 03/0 : 3[1000000] -> 1[e00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151767 [0] NCCL INFO Channel 03/0 : 0[d00000] -> 2[f00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 01/0 : 2[f00000] -> 0[d00000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 04/0 : 1[e00000] -> 3[1000000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 06/0 : 3[1000000] -> 1[e00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151767 [0] NCCL INFO Channel 06/0 : 0[d00000] -> 2[f00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 04/0 : 2[f00000] -> 0[d00000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 05/0 : 1[e00000] -> 3[1000000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 07/0 : 3[1000000] -> 1[e00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151767 [0] NCCL INFO Channel 07/0 : 0[d00000] -> 2[f00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 05/0 : 2[f00000] -> 0[d00000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 08/0 : 1[e00000] -> 3[1000000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 10/0 : 3[1000000] -> 1[e00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151767 [0] NCCL INFO Channel 10/0 : 0[d00000] -> 2[f00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 08/0 : 2[f00000] -> 0[d00000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 09/0 : 1[e00000] -> 3[1000000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 11/0 : 3[1000000] -> 1[e00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151767 [0] NCCL INFO Channel 11/0 : 0[d00000] -> 2[f00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 09/0 : 2[f00000] -> 0[d00000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 12/0 : 1[e00000] -> 3[1000000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 14/0 : 3[1000000] -> 1[e00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151767 [0] NCCL INFO Channel 14/0 : 0[d00000] -> 2[f00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 12/0 : 2[f00000] -> 0[d00000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 13/0 : 1[e00000] -> 3[1000000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 15/0 : 3[1000000] -> 1[e00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151767 [0] NCCL INFO Channel 15/0 : 0[d00000] -> 2[f00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 13/0 : 2[f00000] -> 0[d00000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 00/0 : 3[1000000] -> 2[f00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 02/0 : 1[e00000] -> 0[d00000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 01/0 : 3[1000000] -> 2[f00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 03/0 : 1[e00000] -> 0[d00000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 04/0 : 3[1000000] -> 2[f00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 06/0 : 1[e00000] -> 0[d00000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 05/0 : 3[1000000] -> 2[f00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 07/0 : 1[e00000] -> 0[d00000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 08/0 : 3[1000000] -> 2[f00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 10/0 : 1[e00000] -> 0[d00000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 09/0 : 3[1000000] -> 2[f00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 11/0 : 1[e00000] -> 0[d00000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 12/0 : 3[1000000] -> 2[f00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 14/0 : 1[e00000] -> 0[d00000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 13/0 : 3[1000000] -> 2[f00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 15/0 : 1[e00000] -> 0[d00000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151767 [0] NCCL INFO Connected all rings comm 0x106325f0 nRanks 04 busId d00000
# node-0:4149074:4151767 [0] NCCL INFO Channel 03/0 : 0[d00000] -> 1[e00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Connected all rings comm 0xee1b730 nRanks 04 busId e00000
# node-0:4149074:4151771 [3] NCCL INFO Connected all rings comm 0x11e226c0 nRanks 04 busId 1000000
# node-0:4149074:4151769 [2] NCCL INFO Connected all rings comm 0x106f7dd0 nRanks 04 busId f00000
# node-0:4149074:4151767 [0] NCCL INFO Channel 07/0 : 0[d00000] -> 1[e00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151767 [0] NCCL INFO Channel 11/0 : 0[d00000] -> 1[e00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151767 [0] NCCL INFO Channel 15/0 : 0[d00000] -> 1[e00000] via P2P/direct pointer comm 0x106325f0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 00/0 : 1[e00000] -> 2[f00000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 00/0 : 2[f00000] -> 3[1000000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 04/0 : 1[e00000] -> 2[f00000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 01/0 : 2[f00000] -> 3[1000000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 08/0 : 1[e00000] -> 2[f00000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 04/0 : 2[f00000] -> 3[1000000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 12/0 : 1[e00000] -> 2[f00000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 05/0 : 2[f00000] -> 3[1000000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 08/0 : 2[f00000] -> 3[1000000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 09/0 : 2[f00000] -> 3[1000000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 12/0 : 2[f00000] -> 3[1000000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 13/0 : 2[f00000] -> 3[1000000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 02/0 : 2[f00000] -> 0[d00000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 03/0 : 2[f00000] -> 0[d00000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 06/0 : 2[f00000] -> 0[d00000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 07/0 : 2[f00000] -> 0[d00000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 02/0 : 1[e00000] -> 3[1000000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 01/0 : 3[1000000] -> 1[e00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 10/0 : 2[f00000] -> 0[d00000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 06/0 : 1[e00000] -> 3[1000000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 11/0 : 2[f00000] -> 0[d00000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 05/0 : 3[1000000] -> 1[e00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 10/0 : 1[e00000] -> 3[1000000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 14/0 : 2[f00000] -> 0[d00000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 09/0 : 3[1000000] -> 1[e00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 14/0 : 1[e00000] -> 3[1000000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 15/0 : 2[f00000] -> 0[d00000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 13/0 : 3[1000000] -> 1[e00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 02/0 : 3[1000000] -> 2[f00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 03/0 : 3[1000000] -> 2[f00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 06/0 : 3[1000000] -> 2[f00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 07/0 : 3[1000000] -> 2[f00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 10/0 : 3[1000000] -> 2[f00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 00/0 : 1[e00000] -> 0[d00000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 11/0 : 3[1000000] -> 2[f00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 01/0 : 1[e00000] -> 0[d00000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 14/0 : 3[1000000] -> 2[f00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 04/0 : 1[e00000] -> 0[d00000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151771 [3] NCCL INFO Channel 15/0 : 3[1000000] -> 2[f00000] via P2P/direct pointer comm 0x11e226c0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 05/0 : 1[e00000] -> 0[d00000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 08/0 : 1[e00000] -> 0[d00000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 00/0 : 2[f00000] -> 1[e00000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 09/0 : 1[e00000] -> 0[d00000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 04/0 : 2[f00000] -> 1[e00000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# node-0:4149074:4151768 [1] NCCL INFO Channel 12/0 : 1[e00000] -> 0[d00000] via P2P/direct pointer comm 0xee1b730 nRanks 04
# node-0:4149074:4151769 [2] NCCL INFO Channel 08/0 : 2[f00000] -> 1[e00000] via P2P/direct pointer comm 0x106f7dd0 nRanks 04
# n
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/opt/.singularity/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3524, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_4149074/1093534927.py", line 1, in <cell line: 1>
#     learn.train()
#   File "/opt/conda/envs/ptca/lib/python3.9/site-packages/transformers/trainer.py", line 1885, in train
#     return inner_training_loop(
#   File "/home/aiscuser/scratch/Projects/xcai/xcai/learner.py", line 946, in _inner_training_loop
#     self.update_dataloader_sampler(train_dataloader, epoch, num_train_epochs)
#   File "/home/aiscuser/scratch/Projects/xcai/xcai/learner.py", line 660, in update_dataloader_sampler
#     cluster = self._get_train_data_cluster(epochs_trained, num_train_epochs)
#   File "/home/aiscuser/scratch/Projects/xcai/xcai/learner.py", line 653, in _get_train_data_cluster
#     data_repr = self.get_representation(dataloader)
#   File "/home/aiscuser/scratch/Projects/xcai/xcai/learner.py", line 555, in get_representation
#     with torch.no_grad(): data = getattr(self.model(**inputs), self.args.representation_attribute)
#   File "/opt/conda/envs/ptca/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/opt/conda/envs/ptca/lib/python3.9/site-packages/accelerate/utils/operations.py", line 822, in forward
#     return model_forward(*args, **kwargs)
#   File "/opt/conda/envs/ptca/lib/python3.9/site-packages/accelerate/utils/operations.py", line 810, in __call__
#     return convert_to_fp32(self.model_forward(*args, **kwargs))
#   File "/opt/conda/envs/ptca/lib/python3.9/site-packages/torch/amp/autocast_mode.py", line 14, in decorate_autocast
#     return func(*args, **kwargs)
#   File "/home/aiscuser/scratch/Projects/xcai/xcai/models/PPP0XX.py", line 733, in forward
#     data_o, data_logits, data_repr = self.encoder(data_input_ids=data_input_ids,
#   File "/opt/conda/envs/ptca/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/opt/conda/envs/ptca/lib/python3.9/site-packages/torch/nn/parallel/data_parallel.py", line 171, in forward
#     outputs = self.parallel_apply(replicas, inputs, kwargs)
#   File "/opt/conda/envs/ptca/lib/python3.9/site-packages/torch/nn/parallel/data_parallel.py", line 181, in parallel_apply
#     return parallel_apply(replicas, inputs, kwargs, self.device_ids[:len(replicas)])
#   File "/opt/conda/envs/ptca/lib/python3.9/site-packages/torch/nn/parallel/parallel_apply.py", line 79, in parallel_apply
#     thread.start()
#   File "/opt/conda/envs/ptca/lib/python3.9/threading.py", line 904, in start
#     self._started.wait()
#   File "/opt/conda/envs/ptca/lib/python3.9/threading.py", line 581, in wait
#     signaled = self._cond.wait(timeout)
#   File "/opt/conda/envs/ptca/lib/python3.9/threading.py", line 312, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/.singularity/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2088, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/.singularity/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/opt/.singularity/lib/python3.9/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/opt/.singularity/lib/python3.9/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/opt/conda/envs/ptca/lib/python3.9/inspect.py", line 1543, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/opt/conda/envs/ptca/lib/python3.9/inspect.py", line 1501, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/opt/conda/envs/ptca/lib/python3.9/inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/opt/conda/envs/ptca/lib/python3.9/inspect.py", line 746, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_4149074/1093534927.py in <cell line: 1>()
# ----> 1 learn.train()
#
# /opt/conda/envs/ptca/lib/python3.9/site-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1884         else:
# -> 1885             return inner_training_loop(
#    1886                 args=args,
#
# ~/scratch/Projects/xcai/xcai/learner.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#     945         if self.args.group_by_cluster and (epoch % self.args.num_cluster_update_epochs == 0 or epoch == self.args.num_clustering_warmup_epochs):
# --> 946             self.update_dataloader_sampler(train_dataloader, epoch, num_train_epochs)
#     947
#
# ~/scratch/Projects/xcai/xcai/learner.py in update_dataloader_sampler(self, dataloader, epochs_trained, num_train_epochs)
#     659     if isinstance(dataloader.sampler, ClusterGroupedSampler):
# --> 660         cluster = self._get_train_data_cluster(epochs_trained, num_train_epochs)
#     661         dataloader.sampler.set_cluster(cluster)
#
# ~/scratch/Projects/xcai/xcai/learner.py in _get_train_data_cluster(self, epochs_trained, num_train_epochs)
#     652     dataloader = self.get_test_dataloader(dataset)
# --> 653     data_repr = self.get_representation(dataloader)
#     654     cluster = BalancedClusters.proc(data_repr, self._get_min_cluster_sz(epochs_trained, num_train_epochs))
#
# ~/scratch/Projects/xcai/xcai/learner.py in get_representation(self, dataloader, to_cpu)
#     554         inputs = inputs.to(self.model.device)
# --> 555         with torch.no_grad(): data = getattr(self.model(**inputs), self.args.representation_attribute)
#     556         data_host = self._gather_host_output(data, data_host)
#
# /opt/conda/envs/ptca/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#
# /opt/conda/envs/ptca/lib/python3.9/site-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     821     def forward(*args, **kwargs):
# --> 822         return model_forward(*args, **kwargs)
#     823
#
# /opt/conda/envs/ptca/lib/python3.9/site-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     809     def __call__(self, *args, **kwargs):
# --> 810         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     811
#
# /opt/conda/envs/ptca/lib/python3.9/site-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      13         with autocast_instance:
# ---> 14             return func(*args, **kwargs)
#      15     decorate_autocast.__script_unsupported = '@autocast() decorator is not supported in script mode'  # type: ignore[attr-defined]
#
# ~/scratch/Projects/xcai/xcai/models/PPP0XX.py in forward(self, data_input_ids, data_attention_mask, lbl2data_data2ptr, lbl2data_idx, lbl2data_input_ids, lbl2data_attention_mask, plbl2data_data2ptr, plbl2data_idx, output_attentions, output_hidden_states, return_dict, **kwargs)
#     732
# --> 733         data_o, data_logits, data_repr = self.encoder(data_input_ids=data_input_ids,
#     734                                                       data_attention_mask=data_attention_mask,
#
# /opt/conda/envs/ptca/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#
# /opt/conda/envs/ptca/lib/python3.9/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#     170             replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
# --> 171             outputs = self.parallel_apply(replicas, inputs, kwargs)
#     172             return self.gather(outputs, self.output_device)
#
# /opt/conda/envs/ptca/lib/python3.9/site-packages/torch/nn/parallel/data_parallel.py in parallel_apply(self, replicas, inputs, kwargs)
#     180     def parallel_apply(self, replicas, inputs, kwargs):
# --> 181         return parallel_apply(replicas, inputs, kwargs, self.device_ids[:len(replicas)])
#     182
#
# /opt/conda/envs/ptca/lib/python3.9/site-packages/torch/nn/parallel/parallel_apply.py in parallel_apply(modules, inputs, kwargs_tup, devices)
#      78         for thread in threads:
# ---> 79             thread.start()
#      80         for thread in threads:
#
# /opt/conda/envs/ptca/lib/python3.9/threading.py in start(self)
#     903             raise
# --> 904         self._started.wait()
#     905
#
# /opt/conda/envs/ptca/lib/python3.9/threading.py in wait(self, timeout)
#     580             if not signaled:
# --> 581                 signaled = self._cond.wait(timeout)
#     582             return signaled
#
# /opt/conda/envs/ptca/lib/python3.9/threading.py in wait(self, timeout)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /opt/.singularity/lib/python3.9/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2087                         # in the engines. This should return a list of strings.
# -> 2088                         stb = value._render_traceback_()
#    2089                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /opt/.singularity/lib/python3.9/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2088                         stb = value._render_traceback_()
#    2089                     except Exception:
# -> 2090                         stb = self.InteractiveTB.structured_traceback(etype,
#    2091                                             value, tb, tb_offset=tb_offset)
#    2092
#
# /opt/.singularity/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# /opt/.singularity/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# /opt/.singularity/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# /opt/.singularity/lib/python3.9/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# /opt/.singularity/lib/python3.9/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
#| export
if __name__ == '__main__':
    mp.freeze_support()
    learn.train()
